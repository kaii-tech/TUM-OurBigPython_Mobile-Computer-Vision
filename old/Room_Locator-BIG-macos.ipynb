# %% [markdown]
# # Room Locator (BIG Model)

# %% [markdown]
# ###  Import TensorFlow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import mixed_precision
from matplotlib import pyplot as plt 

# Enable mixed precision for speed and lower memory on M-series GPUs
mixed_precision.set_global_policy("mixed_float16")

# %% [markdown]
# ### Load Image Dataset

# %%
DATA_DIR = "Dataset"
IMG_SIZE = 456
BATCH_SIZE = 64
NUM_CLASSES = 27

AUTOTUNE = tf.data.AUTOTUNE

train_ds = keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="training",
)

val_ds = keras.utils.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="categorical",
    image_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42,
    validation_split=0.2,
    subset="validation",
)

# Pipeline optimizations
train_ds = train_ds.prefetch(AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
# Out:
# Found 6103 files belonging to 27 classes.
# Using 4883 files for training.
# 2026-01-15 11:25:43.952733: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2026-01-15 11:25:43.952755: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2026-01-15 11:25:43.952762: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.66 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768472743.953266 41449788 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1768472743.953333 41449788 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Found 6103 files belonging to 27 classes.
# Using 1220 files for validation.

# %% [markdown]
# ### Add Noise / Randomness

# %%
# Data augmentation tuned for location invariance
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.12),
        layers.RandomZoom(0.15),
        layers.RandomTranslation(0.1, 0.1),
        layers.RandomContrast(0.2),
        layers.RandomBrightness(0.2),
    ],
    name="data_augmentation",
)

# %% [markdown]
# ### Setup and Build Training Model

# %%
# Base model: EfficientNetB5 for higher capacity
base_model = keras.applications.EfficientNetB5(
    include_top=False,
    weights="imagenet",
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
)

# Stage 1: freeze backbone
base_model.trainable = False

inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = keras.applications.efficientnet.preprocess_input(x)

x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D(name="global_avg_pool")(x)

# Lighter classification head with regularization
x = layers.BatchNormalization()(x)
x = layers.Dense(512, activation="relu", kernel_regularizer=keras.regularizers.l2(1e-4))(x)
x = layers.Dropout(0.4)(x)
x = layers.Dense(256, activation="relu", kernel_regularizer=keras.regularizers.l2(1e-4))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax", dtype="float32", name="predictions")(x)

model = keras.Model(inputs, outputs, name="efficientnetB5_tum_locations")

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=[
        "accuracy",
        keras.metrics.TopKCategoricalAccuracy(k=3, name="top_3_acc"),
    ],
)

# %% [markdown]
# ### Execute Training Model

# %%
# Show the model structure and run a short training loop so the cell produces output
model.summary()
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=40,  # increase after verifying things run
    verbose=1,
 )
# Out:
# Model: "efficientnetB5_tum_locations"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 456, 456, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 456, 456, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb5 (Functional)     │ (None, 15, 15, 2048)   │    28,513,527 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_avg_pool                 │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 2048)           │         8,192 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     1,049,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 27)             │         6,939 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,091,982 (122.42 MB)
#  Trainable params: 1,191,451 (4.55 MB)
#  Non-trainable params: 28,517,623 (108.79 MB)
#  Optimizer params: 2,382,908 (9.09 MB)
# Epoch 1/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 532s 7s/step - accuracy: 0.5916 - loss: 3.0122 - top_3_acc: 0.8489 - val_accuracy: 0.7189 - val_loss: 1.3739 - val_top_3_acc: 0.9418
# Epoch 2/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 526s 7s/step - accuracy: 0.6019 - loss: 2.8519 - top_3_acc: 0.8550 - val_accuracy: 0.7328 - val_loss: 1.4893 - val_top_3_acc: 0.9475
# Epoch 3/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 514s 7s/step - accuracy: 0.6005 - loss: 2.7676 - top_3_acc: 0.8583 - val_accuracy: 0.7213 - val_loss: 1.7020 - val_top_3_acc: 0.9311
# Epoch 4/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 511s 7s/step - accuracy: 0.6279 - loss: 2.6338 - top_3_acc: 0.8661 - val_accuracy: 0.7303 - val_loss: 1.7083 - val_top_3_acc: 0.9459
# Epoch 5/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 503s 7s/step - accuracy: 0.6295 - loss: 2.5300 - top_3_acc: 0.8700 - val_accuracy: 0.7402 - val_loss: 1.6908 - val_top_3_acc: 0.9451
# Epoch 6/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 507s 7s/step - accuracy: 0.6336 - loss: 2.4424 - top_3_acc: 0.8781 - val_accuracy: 0.7598 - val_loss: 1.6418 - val_top_3_acc: 0.9484
# Epoch 7/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 511s 7s/step - accuracy: 0.6285 - loss: 2.4050 - top_3_acc: 0.8822 - val_accuracy: 0.7426 - val_loss: 1.6477 - val_top_3_acc: 0.9500
# Epoch 8/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 507s 7s/step - accuracy: 0.6318 - loss: 2.3291 - top_3_acc: 0.8833 - val_accuracy: 0.7500 - val_loss: 1.6335 - val_top_3_acc: 0.9508
# Epoch 9/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 502s 7s/step - accuracy: 0.6443 - loss: 2.2096 - top_3_acc: 0.8919 - val_accuracy: 0.7402 - val_loss: 1.5872 - val_top_3_acc: 0.9410
# Epoch 10/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 507s 7s/step - accuracy: 0.6551 - loss: 2.1140 - top_3_acc: 0.8896 - val_accuracy: 0.7623 - val_loss: 1.5407 - val_top_3_acc: 0.9467
# Epoch 11/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 501s 6s/step - accuracy: 0.6650 - loss: 2.0532 - top_3_acc: 0.8958 - val_accuracy: 0.7500 - val_loss: 1.6259 - val_top_3_acc: 0.9443
# Epoch 12/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 527s 7s/step - accuracy: 0.6539 - loss: 1.9664 - top_3_acc: 0.8962 - val_accuracy: 0.7533 - val_loss: 1.4941 - val_top_3_acc: 0.9549
# Epoch 13/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 516s 7s/step - accuracy: 0.6703 - loss: 1.8376 - top_3_acc: 0.9087 - val_accuracy: 0.7418 - val_loss: 1.5201 - val_top_3_acc: 0.9516
# Epoch 14/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 517s 7s/step - accuracy: 0.6697 - loss: 1.8508 - top_3_acc: 0.8970 - val_accuracy: 0.7459 - val_loss: 1.4942 - val_top_3_acc: 0.9459
# Epoch 15/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 512s 7s/step - accuracy: 0.6805 - loss: 1.7814 - top_3_acc: 0.9029 - val_accuracy: 0.7631 - val_loss: 1.3917 - val_top_3_acc: 0.9525
# Epoch 16/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 519s 7s/step - accuracy: 0.6828 - loss: 1.7044 - top_3_acc: 0.9103 - val_accuracy: 0.7262 - val_loss: 1.4680 - val_top_3_acc: 0.9451
# Epoch 17/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 516s 7s/step - accuracy: 0.6689 - loss: 1.7099 - top_3_acc: 0.9101 - val_accuracy: 0.7590 - val_loss: 1.3194 - val_top_3_acc: 0.9590
# Epoch 18/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 519s 7s/step - accuracy: 0.6869 - loss: 1.6294 - top_3_acc: 0.9160 - val_accuracy: 0.7557 - val_loss: 1.3558 - val_top_3_acc: 0.9500
# Epoch 19/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 508s 7s/step - accuracy: 0.6936 - loss: 1.6013 - top_3_acc: 0.9195 - val_accuracy: 0.7484 - val_loss: 1.3658 - val_top_3_acc: 0.9484
# Epoch 20/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 514s 7s/step - accuracy: 0.6947 - loss: 1.5765 - top_3_acc: 0.9187 - val_accuracy: 0.7656 - val_loss: 1.3091 - val_top_3_acc: 0.9500
# Epoch 21/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 511s 7s/step - accuracy: 0.6990 - loss: 1.5323 - top_3_acc: 0.9224 - val_accuracy: 0.7598 - val_loss: 1.2614 - val_top_3_acc: 0.9607
# Epoch 22/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 514s 7s/step - accuracy: 0.7016 - loss: 1.4990 - top_3_acc: 0.9207 - val_accuracy: 0.7631 - val_loss: 1.2464 - val_top_3_acc: 0.9557
# Epoch 23/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 517s 7s/step - accuracy: 0.7119 - loss: 1.4740 - top_3_acc: 0.9238 - val_accuracy: 0.7508 - val_loss: 1.2910 - val_top_3_acc: 0.9557
# Epoch 24/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 512s 7s/step - accuracy: 0.7137 - loss: 1.4493 - top_3_acc: 0.9283 - val_accuracy: 0.7721 - val_loss: 1.2403 - val_top_3_acc: 0.9508
# Epoch 25/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 505s 7s/step - accuracy: 0.7096 - loss: 1.4576 - top_3_acc: 0.9275 - val_accuracy: 0.7492 - val_loss: 1.3603 - val_top_3_acc: 0.9369
# Epoch 26/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 515s 7s/step - accuracy: 0.7123 - loss: 1.4591 - top_3_acc: 0.9263 - val_accuracy: 0.7828 - val_loss: 1.2190 - val_top_3_acc: 0.9582
# Epoch 27/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 515s 7s/step - accuracy: 0.7235 - loss: 1.4107 - top_3_acc: 0.9326 - val_accuracy: 0.7672 - val_loss: 1.2611 - val_top_3_acc: 0.9574
# Epoch 28/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 515s 7s/step - accuracy: 0.7184 - loss: 1.4296 - top_3_acc: 0.9281 - val_accuracy: 0.7393 - val_loss: 1.3367 - val_top_3_acc: 0.9385
# Epoch 29/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 518s 7s/step - accuracy: 0.7237 - loss: 1.4041 - top_3_acc: 0.9324 - val_accuracy: 0.7631 - val_loss: 1.2423 - val_top_3_acc: 0.9508
# Epoch 30/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 511s 7s/step - accuracy: 0.7248 - loss: 1.4296 - top_3_acc: 0.9287 - val_accuracy: 0.7648 - val_loss: 1.3170 - val_top_3_acc: 0.9377
# Epoch 31/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 509s 7s/step - accuracy: 0.7262 - loss: 1.4176 - top_3_acc: 0.9312 - val_accuracy: 0.7434 - val_loss: 1.3473 - val_top_3_acc: 0.9402
# Epoch 32/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 518s 7s/step - accuracy: 0.7239 - loss: 1.4049 - top_3_acc: 0.9314 - val_accuracy: 0.7516 - val_loss: 1.2944 - val_top_3_acc: 0.9426
# Epoch 33/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 518s 7s/step - accuracy: 0.7164 - loss: 1.4471 - top_3_acc: 0.9255 - val_accuracy: 0.7795 - val_loss: 1.2121 - val_top_3_acc: 0.9607
# Epoch 34/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 503s 7s/step - accuracy: 0.7123 - loss: 1.4492 - top_3_acc: 0.9279 - val_accuracy: 0.7369 - val_loss: 1.3688 - val_top_3_acc: 0.9451
# Epoch 35/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 506s 7s/step - accuracy: 0.7194 - loss: 1.4776 - top_3_acc: 0.9230 - val_accuracy: 0.7459 - val_loss: 1.3656 - val_top_3_acc: 0.9418
# Epoch 36/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 514s 7s/step - accuracy: 0.7264 - loss: 1.4355 - top_3_acc: 0.9314 - val_accuracy: 0.7500 - val_loss: 1.3188 - val_top_3_acc: 0.9492
# Epoch 37/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 515s 7s/step - accuracy: 0.7145 - loss: 1.5041 - top_3_acc: 0.9201 - val_accuracy: 0.7270 - val_loss: 1.4516 - val_top_3_acc: 0.9344
# Epoch 38/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 519s 7s/step - accuracy: 0.7112 - loss: 1.5134 - top_3_acc: 0.9218 - val_accuracy: 0.7623 - val_loss: 1.3087 - val_top_3_acc: 0.9566
# Epoch 39/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 514s 7s/step - accuracy: 0.7151 - loss: 1.5323 - top_3_acc: 0.9154 - val_accuracy: 0.7705 - val_loss: 1.3536 - val_top_3_acc: 0.9484
# Epoch 40/40
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 518s 7s/step - accuracy: 0.7094 - loss: 1.5622 - top_3_acc: 0.9162 - val_accuracy: 0.7254 - val_loss: 1.4120 - val_top_3_acc: 0.9443

# %% [markdown]
# ### Plot Epocs

# %%
plt.plot(history.epoch, history.history["loss"])
plt.title("Train Loss Curve")
plt.show()

plt.plot(history.epoch, history.history["accuracy"])
plt.title("Train Accuracy Curve")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.plot(history.epoch, history.history["loss"])
#       2 plt.title("Train Loss Curve")
#       3 plt.show()
#
# NameError: name 'history' is not defined

# %% [markdown]
# ### Fine-Tuning Model

# %%
# Unfreeze top blocks of EfficientNetB5 for fine-tuning
base_model.trainable = True

fine_tune_at = len(base_model.layers) * 3 // 4  # top ~25% of layers

for i, layer in enumerate(base_model.layers):
    layer.trainable = i >= fine_tune_at
    # Keep BatchNorm in eval mode for stability
    if isinstance(layer, layers.BatchNormalization):
        layer.trainable = False

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-5),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
    metrics=[
        "accuracy",
        keras.metrics.TopKCategoricalAccuracy(k=3, name="top_3_acc"),
    ],
)

# Then train again with early stopping + LR schedule
early_stopping = keras.callbacks.EarlyStopping(
    monitor="val_accuracy",
    patience=3,
    restore_best_weights=True,
 )
